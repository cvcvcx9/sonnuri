# %% [markdown]
# # Hand-to-Hand Text2Keypoint
#
# <br/>
#
# - [Github Repository](https://github.com/Tobigs-team/hand-to-hand)
#
# - [Web Page](https://hand-to-hand.kro.kr/public/)
#
# <br/>
#
# This notebook file is provided for executing source code in Google Colab using GPU.

# %% [markdown]
# ### 1. Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2. Set your own directory

# %%
# example
cd "/content/drive/Shareddrives"

# %% [markdown]
# ### 3. Git Clone

# %%
# !git clone https://github.com/Tobigs-team/hand-to-hand.git

# %% [markdown]
# ### 4. Move to text2keypoint directory

# %%
cd "/content/drive/Shareddrives/hand-to-hand/text2keypoint"
# Out:
# [WinError 3] 지정된 경로를 찾을 수 없습니다: '/content/drive/Shareddrives/hand-to-hand/text2keypoint'
# c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint
# c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\venv\lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %% [markdown]
# ### 5. Set the mode in `Base.yaml`

# %% [markdown]
# - `mode`: "Train" or "Test"
#     - if "Test" -> `test_mode`: "recent" or "best"

# %% [markdown]
# ### 5. Execute `__main__.py`

# %%
# !python __main__.py
# Out:
# ---------------------------------------------------
# Complete: Load train, dev data
# ---------------------------------------------------
# ---------------------------------------------------
# Complete: Make result directories
# ---------------------------------------------------
# save path
# ./Models/result/img_video/real/SEN0054_REAL06_카드_1회_되다_real/
# 2024-10-29 16:04:27.061217: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-10-29 16:04:27.061418: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-10-29 16:04:31.631677: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-10-29 16:04:31.632309: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-10-29 16:04:31.632866: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-10-29 16:04:31.633447: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-10-29 16:04:31.633983: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-10-29 16:04:31.634587: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-10-29 16:04:31.635173: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-10-29 16:04:31.635774: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-10-29 16:04:31.635973: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-10-29 16:04:31.636619: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint\__main__.py", line 23, in <module>
#     main()
#   File "c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint\__main__.py", line 17, in main
#     Train(cfg = cfg)
#   File "c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint\train.py", line 123, in Train
#     create_img_video(real_json_path, real_img_path, filename)
#   File "c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint\modeling\key2video.py", line 124, in create_img_video
#     create_video(save_path)
#   File "c:\Users\SSAFY\Desktop\A301\test\Hand-to-Hand\text2keypoint\modeling\key2video.py", line 91, in create_video
#     out = cv2.VideoWriter(save_path + str(images[0])[:-8] + '.mp4', cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
# IndexError: list index out of range
